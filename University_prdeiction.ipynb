# %% [markdown]
# TASK #1: UNDERSTAND THE PROBLEM STATEMENT

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the csv file 
df = pd.read_csv("Admission_Predict.csv")

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0           1        337          118  ...  9.65         1             0.92
# 1           2        324          107  ...  8.87         1             0.76
# 2           3        316          104  ...  8.00         1             0.72
# 3           4        322          110  ...  8.67         1             0.80
# 4           5        314          103  ...  8.21         0             0.65
#
# [5 rows x 9 columns]

# %%
# Let's drop the serial no.
df.drop('Serial No.', axis=1, inplace=True)
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  ...  CGPA  Research  Chance of Admit
# 0        337          118                  4  ...  9.65         1             0.92
# 1        324          107                  4  ...  8.87         1             0.76
# 2        316          104                  3  ...  8.00         1             0.72
# 3        322          110                  3  ...  8.67         1             0.80
# 4        314          103                  2  ...  8.21         0             0.65
#
# [5 rows x 8 columns]

# %%
# checking the null values
df.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
# Check the dataframe information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
# Statistical summary of the dataframe
df.describe()
# Out:
#         GRE Score  TOEFL Score  ...    Research  Chance of Admit
# count  500.000000   500.000000  ...  500.000000        500.00000
# mean   316.472000   107.192000  ...    0.560000          0.72174
# std     11.295148     6.081868  ...    0.496884          0.14114
# min    290.000000    92.000000  ...    0.000000          0.34000
# 25%    308.000000   103.000000  ...    0.000000          0.63000
# 50%    317.000000   107.000000  ...    1.000000          0.72000
# 75%    325.000000   112.000000  ...    1.000000          0.82000
# max    340.000000   120.000000  ...    1.000000          0.97000
#
# [8 rows x 8 columns]

# %%
# Grouping by University ranking
df1 = df.groupby(by = 'University Rating').mean()
df1
# Out:
#                     GRE Score  TOEFL Score  ...  Research  Chance of Admit
# University Rating                           ...
# 1                  304.911765   100.205882  ...  0.294118         0.562059
# 2                  309.134921   103.444444  ...  0.293651         0.626111
# 3                  315.030864   106.314815  ...  0.537037         0.702901
# 4                  323.304762   110.961905  ...  0.780952         0.801619
# 5                  327.890411   113.438356  ...  0.876712         0.888082
#
# [5 rows x 7 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Returns: matplotlib.AxesSubplot or numpy.ndarray of them

# %%
df.hist(bins =30, figsize=(20,20), color ='r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7105860f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe710532470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7105606d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7105107f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7104c1a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe710472cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7104a2f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe71045f198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe71045f208>]],
#       dtype=object)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.pairplot(df)

# %%
corr_matrix = df.corr()

# %%
plt.figure(num=None, figsize=(12, 12))

# %%
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')

# %%
x = df.drop(columns = ['Chance of Admit'])
y = df['Chance of Admit']

# %%
x.shape
# Out:
# (500, 7)

# %%
y.shape
# Out:
# (500,)

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit, Length: 500, dtype: float64

# %%
x = np.array(x)
y = np.array(y)

# %%
y = y.reshape(-1,1)
y.shape
# Out:
# (500, 1)

# %%
# scaling the data before training the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scalar_x = StandardScaler()
x = scalar_x.fit_transform(x)

# %%
scalar_y = StandardScaler()
y = scalar_y.fit_transform(y)

# %%
# spliting the data in to test and train sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
accuracy = model.score(x_test, y_test)
accuracy
# Out:
# 0.8513819208753379

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam

# %%
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 7))
ANN_model.add(Activation('relu'))

ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))

ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))

ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dropout(0.999999999999999))

ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_44 (Dense)             (None, 50)                400
# _________________________________________________________________
# activation_44 (Activation)   (None, 50)                0
# _________________________________________________________________
# dense_45 (Dense)             (None, 150)               7650
# _________________________________________________________________
# activation_45 (Activation)   (None, 150)               0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 150)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 150)               22650
# _________________________________________________________________
# activation_46 (Activation)   (None, 150)               0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 150)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 50)                7550
# _________________________________________________________________
# activation_47 (Activation)   (None, 50)                0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 50)                0
# =================================================================
# Total params: 38,250
# Trainable params: 38,250
# Non-trainable params: 0
# _________________________________________________________________

# %%
ANN_model.compile(optimizer = 'Adam', loss = 'mean_squared_error')

# %%
epoch_hist = ANN_model.fit(x_train, y_train, epochs = 100, batch_size=20)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 2/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 3/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 4/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 5/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 6/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 7/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 8/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 9/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 10/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 11/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 12/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 13/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 14/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 15/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 16/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 17/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 18/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 19/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 20/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 21/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 22/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 23/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 24/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 25/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 26/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 27/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 28/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 29/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 30/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 31/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 32/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 33/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 34/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 35/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 36/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 37/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 38/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 39/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 40/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 41/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 42/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 43/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 44/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 45/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 46/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 47/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 48/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 49/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 50/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 51/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 52/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 53/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 54/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 55/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 56/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 57/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 58/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 59/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 60/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 61/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 62/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 63/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 64/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 65/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 66/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 67/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 68/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 69/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 70/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 71/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 72/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 73/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 74/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 75/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 76/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 77/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 78/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 79/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 80/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 81/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 82/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 83/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 84/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 85/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 86/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 87/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 88/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 89/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 90/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 91/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 92/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 93/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 94/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 95/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 96/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 97/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 98/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 99/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136
# Epoch 100/100
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0136

# %%
result = ANN_model.evaluate(x_test, y_test)
accuracy_ANN = 1 - result
print("Accuracy: {}".format(accuracy_ANN))
# Out:
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9432
# Accuracy: 0.05676066875457764

# %%
epoch_hist.history.keys()
# Out:
# dict_keys(['loss'])

# %%
plt.plot(epoch_hist.history['loss'])
plt.title('Model loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.legend(['Training Loss'])

# %%
# Decision tree builds regression or classification models in the form of a tree structure. 
# Decision tree breaks down a dataset into smaller subsets while at the same time an associated decision tree is incrementally developed. 
# The final result is a tree with decision nodes and leaf nodes.
# Great resource: https://www.saedsayad.com/decision_tree_reg.html
from sklearn.tree import DecisionTreeRegressor
Decision_model = DecisionTreeRegressor()
Decision_model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
accuracy_tree = Decision_model.score(x_test, y_test)
accuracy_tree
# Out:
# 0.711921492609644

# %%
# Many decision Trees make up a random forest model which is an ensemble model. 
# Predictions made by each decision tree are averaged to get the prediction of random forest model.
# A random forest regressor fits a number of classifying decision trees on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting. 
from sklearn.ensemble import RandomForestRegressor
Random_model = RandomForestRegressor(n_estimators=100, max_depth = 10)
Random_model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=10, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
accuracy_forest = Random_model.score(x_test, y_test)
accuracy_forest
# Out:
# 0.8251170413514138

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
y_predict = model.predict(x_test)
plt.plot(y_test, y_predict, '^', color='r')

# %%
y_predict_orig = scalar_y.inverse_transform(y_predict)
y_test_orig = scalar_y.inverse_transform(y_test)

# %%
plt.plot(y_test, y_predict_orig, '^', color = 'r')

# %%
k = x_test.shape[1]
n = len(x_test)
n
# Out:
# 75

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 0.052
# MSE = 0.002725985833544357
# MAE = 0.03686257451703116
# R2 = 0.8513819208753379
# Adjusted R2 = 0.8358546588772389
